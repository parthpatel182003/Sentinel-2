# %% [markdown]
# # 04 Compare Results
#
# This notebook compares the classical baseline and the deep learning model on the same evaluation scenes.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import sys
from pathlib import Path

REPO_ROOT = Path('/content/WaterDetectionProjectRepo')
if REPO_ROOT.exists() and str(REPO_ROOT) not in sys.path:
    sys.path.append(str(REPO_ROOT))

from src.config import PATHS, ensure_project_dirs

ensure_project_dirs()
PATHS['reports_root']

# %% [markdown]
# ## To Implement
#
# - load predictions from Phase 1 and Phase 2
# - compute IoU, Dice, Precision, and Recall
# - compare water area estimates
# - visualize agreement and disagreement maps
# - summarize strengths, weaknesses, and practical insights
